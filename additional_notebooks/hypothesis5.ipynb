# %%
invoices["Region"] = invoices["Region"].astype(float)

# %%
invoices.dtypes
# Out:
# ShipRegion        object
# Invoice_total    float64
# Avg_cost         float64
# Region           float64
# dtype: object

# %%
invoices.drop(columns="ShipRegion", inplace=True)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
invoices.hist(figsize=(15,20))
plt.show()

# %%
pd.read_sql_query("SELECT * FROM Shipper limit 3", conn)
# Out:
#    Id       CompanyName           Phone
# 0   1    Speedy Express  (503) 555-9831
# 1   2    United Package  (503) 555-3199
# 2   3  Federal Shipping  (503) 555-9931

# %%
pd.read_sql_query("SELECT * FROM [Product] limit 3", conn)
# Out:
#    Id    ProductName  SupplierId  CategoryId      QuantityPerUnit  UnitPrice  \
# 0   1           Chai           1           1   10 boxes x 20 bags         18
# 1   2          Chang           1           1   24 - 12 oz bottles         19
# 2   3  Aniseed Syrup           1           2  12 - 550 ml bottles         10
#
#    UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0            39             0            10             0
# 1            17            40            25             0
# 2            13            70            25             0

# %%
pd.read_sql_query("SELECT * FROM [Order] ORDER BY ShipRegion", conn)
# Out:
#         Id CustomerId  EmployeeId   OrderDate RequiredDate ShippedDate  \
# 0    10289      BSBEV           7  2012-08-26   2012-09-23  2012-08-28
# 1    10298      HUNGO           6  2012-09-05   2012-10-03  2012-09-11
# 2    10309      HUNGO           3  2012-09-19   2012-10-17  2012-10-23
# 3    10315      ISLAT           4  2012-09-26   2012-10-24  2012-10-03
# 4    10318      ISLAT           8  2012-10-01   2012-10-29  2012-10-04
# 5    10321      ISLAT           3  2012-10-03   2012-10-31  2012-10-11
# 6    10335      HUNGO           7  2012-10-22   2012-11-19  2012-10-24
# 7    10355      AROUT           6  2012-11-15   2012-12-13  2012-11-20
# 8    10359      SEVES           5  2012-11-21   2012-12-19  2012-11-26
# 9    10364      EASTC           1  2012-11-26   2013-01-07  2012-12-04
# 10   10373      HUNGO           4  2012-12-05   2013-01-02  2012-12-11
# 11   10377      SEVES           1  2012-12-09   2013-01-06  2012-12-13
# 12   10380      HUNGO           8  2012-12-12   2013-01-09  2013-01-16
# 13   10383      AROUT           8  2012-12-16   2013-01-13  2012-12-18
# 14   10388      SEVES           2  2012-12-19   2013-01-16  2012-12-20
# 15   10400      EASTC           1  2013-01-01   2013-01-29  2013-01-16
# 16   10429      HUNGO           3  2013-01-29   2013-03-12  2013-02-07
# 17   10435      CONSH           8  2013-02-04   2013-03-18  2013-02-07
# 18   10453      AROUT           1  2013-02-21   2013-03-21  2013-02-26
# 19   10462      CONSH           2  2013-03-03   2013-03-31  2013-03-18
# 20   10471      BSBEV           2  2013-03-11   2013-04-08  2013-03-18
# 21   10472      SEVES           8  2013-03-12   2013-04-09  2013-03-19
# 22   10473      ISLAT           1  2013-03-13   2013-03-27  2013-03-21
# 23   10484      BSBEV           3  2013-03-24   2013-04-21  2013-04-01
# 24   10503      HUNGO           6  2013-04-11   2013-05-09  2013-04-16
# 25   10516      HUNGO           2  2013-04-24   2013-05-22  2013-05-01
# 26   10517      NORTS           3  2013-04-24   2013-05-22  2013-04-29
# 16         2    56.63  Hungry Owl All-Night Grocers
# 17         2     9.21         Consolidated Holdings
# 18         2    25.36               Around the Horn
# 19         1     6.17         Consolidated Holdings
# 20         3    45.59                 B's Beverages
# 21         1     4.20            Seven Seas Imports
# 22         3    16.37                Island Trading
# 23         3     6.88                 B's Beverages
# 24         2    16.74  Hungry Owl All-Night Grocers
# 25         3    62.78  Hungry Owl All-Night Grocers
# 26         3    32.07                   North/South
# 27         2    77.63            Seven Seas Imports
# 28         3    74.46            Eastern Connection
# 29         3     4.87                 B's Beverages
# ..       ...      ...                           ...
# 800        2    32.82                  Maison Dewey
# 801        2   353.07                  Ernst Handel
# 802        3   117.61                  Ernst Handel
# 803        1    38.51                    QUICK-Stop
# 804        2     1.12                    QUICK-Stop
# 805        2    96.35            Ottilies Käseladen
# 806        1    44.84                  Maison Dewey
# 807        3    79.46                  Ernst Handel
# 808        1     1.21          Alfred's Futterkiste
# 809        3   242.95                Frankenversand
# 810        2   754.26                  Ernst Handel
# 811        2    43.30            Ottilies Käseladen
# 812        1   297.18                    QUICK-Stop
# 813        1    29.59               Königlich Essen
# 814        1    47.84             Chop-suey Chinese
# 815        3    84.74            Richter Supermarkt
# 816        2     0.17              Suprêmes délices
# 817        3   149.47      Drachenblut Delikatessen
# 818        2    29.59              Suprêmes délices
# 819        2    48.22             Chop-suey Chinese
# 820        2     8.80          Spécialités du monde
# 821        2    71.64             Die Wandernde Kuh
# 822        3     2.79              La maison d'Asie
# 823        2    53.05              Piccolo und mehr
# 824        3    31.14       Blauer See Delikatessen
# 825        2     7.98      Drachenblut Delikatessen
# 826        1   136.00           Lehmanns Marktstand
# 827        2   258.64                  Ernst Handel
# 828        2     6.19            Richter Supermarkt
# 829        2    38.28                      Bon app'
#
#                        ShipAddress        ShipCity      ShipRegion  \
# 0                Fauntleroy Circus          London   British Isles
# 1                 8 Johnstown Road            Cork   British Isles
# 2                 8 Johnstown Road            Cork   British Isles
# 3        Garden House Crowther Way           Cowes   British Isles
# 4        Garden House Crowther Way           Cowes   British Isles
# 5        Garden House Crowther Way           Cowes   British Isles
# 6                 8 Johnstown Road            Cork   British Isles
# 7    Brook Farm Stratford St. Mary      Colchester   British Isles
# 8                  90 Wadhurst Rd.          London   British Isles
# 9                   35 King George          London   British Isles
# 10                8 Johnstown Road            Cork   British Isles
# 11                 90 Wadhurst Rd.          London   British Isles
# 12                8 Johnstown Road            Cork   British Isles
# 13   Brook Farm Stratford St. Mary      Colchester   British Isles
# 14                 90 Wadhurst Rd.          London   British Isles
# 15                  35 King George          London   British Isles
# 16                8 Johnstown Road            Cork   British Isles
# 17    Berkeley Gardens 12  Brewery          London   British Isles
# 18   Brook Farm Stratford St. Mary      Colchester   British Isles
# 19    Berkeley Gardens 12  Brewery          London   British Isles
# 20               Fauntleroy Circus          London   British Isles
# 21                 90 Wadhurst Rd.          London   British Isles
# 22       Garden House Crowther Way           Cowes   British Isles
# 23               Fauntleroy Circus          London   British Isles
# 24                8 Johnstown Road            Cork   British Isles
# 811          50739      Germany
# 812          01307      Germany
# 813          14776      Germany
# 814           3012  Switzerland
# 815           1204  Switzerland
# 816         B-6000      Belgium
# 817          52066      Germany
# 818         B-6000      Belgium
# 819           3012  Switzerland
# 820          75016       France
# 821          70563      Germany
# 822          31000       France
# 823           5020      Austria
# 824          68306      Germany
# 825          52066      Germany
# 826          60528      Germany
# 827           8010      Austria
# 828           1204  Switzerland
# 829          13008       France
#
# [830 rows x 14 columns]

# %%
pd.read_sql_query('''Select * FROM Product 
                    INNER JOIN Category on Product.CategoryId = Category.Id 
                    Where Discontinued == 0
                    ORDER BY CATEGORYNAME''',conn)
# Out:
#     Id                       ProductName  SupplierId  CategoryId  \
# 0    1                              Chai           1           1
# 1    2                             Chang           1           1
# 2   34                     Sasquatch Ale          16           1
# 3   35                    Steeleye Stout          16           1
# 4   38                     Côte de Blaye          18           1
# 5   39                  Chartreuse verte          18           1
# 6   43                       Ipoh Coffee          20           1
# 7   67         Laughing Lumberjack Lager          16           1
# 8   70                     Outback Lager           7           1
# 9   75              Rhönbräu Klosterbier          12           1
# 10  76                      Lakkalikööri          23           1
# 11   3                     Aniseed Syrup           1           2
# 12   4      Chef Anton's Cajun Seasoning           2           2
# 13   6      Grandma's Boysenberry Spread           3           2
# 14   8        Northwoods Cranberry Sauce           3           2
# 15  15                      Genen Shouyu           6           2
# 16  44                      Gula Malacca          20           2
# 17  61                    Sirop d'érable          29           2
# 18  63                      Vegie-spread           7           2
# 19  65  Louisiana Fiery Hot Pepper Sauce           2           2
# 20  66         Louisiana Hot Spiced Okra           2           2
# 21  77   Original Frankfurter grüne Soße          12           2
# 22  16                           Pavlova           7           3
# 23  19        Teatime Chocolate Biscuits           8           3
# 24  20            Sir Rodney's Marmalade           8           3
# 25  21               Sir Rodney's Scones           8           3
# 26  25           NuNuCa Nuß-Nougat-Creme          11           3
# 27  26               Gumbär Gummibärchen          11           3
# 28  27                Schoggi Schokolade          11           3
# 29  47                     Zaanse koeken          22           3
# ..  ..                               ...         ...         ...
# 39  33                           Geitost          15           4
# 40  59              Raclette Courdavault          28           4
# 41  60                 Camembert Pierrot          28           4
# 42  69                  Gudbrandsdalsost          15           4
# 43  71                       Flotemysost          15           4
# 44  72            Mozzarella di Giovanni          14           4
# 45  22               Gustaf's Knäckebröd           9           5
# 46  23                          Tunnbröd           9           5
# 47  52                          Filo Mix          24           5
# 48  56            Gnocchi di nonna Alice          26           5
# 49  57                    Ravioli Angelo          26           5
# 50  64         Wimmers gute Semmelknödel          12           5
# 51  54                         Tourtière          25           6
# 52  55                      Pâté chinois          25           6
# 53   7   Uncle Bob's Organic Dried Pears           3           7
# 54  14                              Tofu           6           7
# 55  51             Manjimup Dried Apples          24           7
# 56  74                     Longlife Tofu           4           7
# 57  10                             Ikura           4           8
# 58  13                             Konbu           6           8
# 59  18                  Carnarvon Tigers           7           8
# 60  30             Nord-Ost Matjeshering          13           8
# 61  36                       Inlagd Sill          17           8
# 62  37                        Gravad lax          17           8
# 63  40                  Boston Crab Meat          19           8
# 64  41   Jack's New England Clam Chowder          19           8
# 65  45                       Rogede sild          21           8
# 66  46                         Spegesild          21           8
# 67  58            Escargots de Bourgogne          27           8
# 68  73                        Röd Kaviar          17           8
#
#          QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 
# 63        24 - 4 oz tins      18.40           123             0            30
# 64       12 - 12 oz cans       9.65            85             0            10
# 65               1k pkg.       9.50             5            70            15
# 66     4 - 450 g glasses      12.00            95             0             0
# 67             24 pieces      13.25            62             0            20
# 68       24 - 150 g jars      15.00           101             0             5
#
#     Discontinued  Id    CategoryName  \
# 0              0   1       Beverages
# 1              0   1       Beverages
# 2              0   1       Beverages
# 3              0   1       Beverages
# 4              0   1       Beverages
# 5              0   1       Beverages
# 6              0   1       Beverages
# 7              0   1       Beverages
# 8              0   1       Beverages
# 9              0   1       Beverages
# 10             0   1       Beverages
# 11             0   2      Condiments
# 12             0   2      Condiments
# 13             0   2      Condiments
# 14             0   2      Condiments
# 15             0   2      Condiments
# 16             0   2      Condiments
# 17             0   2      Condiments
# 18             0   2      Condiments
# 19             0   2      Condiments
# 20             0   2      Condiments
# 21             0   2      Condiments
# 22             0   3     Confections
# 23             0   3     Confections
# 24             0   3     Confections
# 25             0   3     Confections
# 26             0   3     Confections
# 27             0   3     Confections
# 28             0   3     Confections
# 29             0   3     Confections
# ..           ...  ..             ...
# 39             0   4  Dairy Products
# 40             0   4  Dairy Products
# 41             0   4  Dairy Products
# 42             0   4  Dairy Products
# 43             0   4  Dairy Products
# 44             0   4  Dairy Products
# 45             0   5  Grains/Cereals
# 46             0   5  Grains/Cereals
# 47             0   5  Grains/Cereals
# 48             0   5  Grains/Cereals
# 49             0   5  Grains/Cereals
# 50             0   5  Grains/Cereals
# 51             0   6    Meat/Poultry
# 52             0   6    Meat/Poultry
# 53             0   7         Produce
# 54             0   7         Produce
# 55             0   7         Produce
# 56             0   7         Produce
# 57             0   8         Seafood
# 58             0   8         Seafood
# 59             0   8         Seafood
# 60             0   8         Seafood
# 61             0   8         Seafood
# 62             0   8         Seafood
# 63             0   8         Seafood
# 64             0   8         Seafood
# 65             0   8         Seafood
# 66             0   8         Seafood
# 67             0   8         Seafood
# 68             0   8         Seafood
#
#                                           Description
# 0         Soft drinks, coffees, teas, beers, and ales
# 1         Soft drinks, coffees, teas, beers, and ales
# 2         Soft drinks, coffees, teas, beers, and ales
# 3         Soft drinks, coffees, teas, beers, and ales
# 4         Soft drinks, coffees, teas, beers, and ales
# 5         Soft drinks, coffees, teas, beers, and ales
# 6         Soft drinks, coffees, teas, beers, and ales
# 7         Soft drinks, coffees, teas, beers, and ales
# 8         Soft drinks, coffees, teas, beers, and ales
# 9         Soft drinks, coffees, teas, beers, and ales
# 10        Soft drinks, coffees, teas, beers, and ales
# 11  Sweet and savory sauces, relishes, spreads, an...
# 12  Sweet and savory sauces, relishes, spreads, an...
# 13  Sweet and savory sauces, relishes, spreads, an...
# 14  Sweet and savory sauces, relishes, spreads, an...
# 15  Sweet and savory sauces, relishes, spreads, an...
# 16  Sweet and savory sauces, relishes, spreads, an...
# 17  Sweet and savory sauces, relishes, spreads, an...
# 18  Sweet and savory sauces, relishes, spreads, an...
# 19  Sweet and savory sauces, relishes, spreads, an...
# 20  Sweet and savory sauces, relishes, spreads, an...
# 21  Sweet and savory sauces, relishes, spreads, an...
# 22                Desserts, candies, and sweet breads
# 23                Desserts, candies, and sweet breads
# 24                Desserts, candies, and sweet breads
# 25                Desserts, candies, and sweet breads
# 26                Desserts, candies, and sweet breads
# 27                Desserts, candies, and sweet breads
# 28                Desserts, candies, and sweet breads
# 29                Desserts, candies, and sweet breads
# ..                                                ...
# 39                                            Cheeses
# 40                                            Cheeses
# 41                                            Cheeses
# 42                                            Cheeses
# 43                                            Cheeses
# 44                                            Cheeses
# 45                Breads, crackers, pasta, and cereal
# 46                Breads, crackers, pasta, and cereal
# 47                Breads, crackers, pasta, and cereal
# 48                Breads, crackers, pasta, and cereal
# 49                Breads, crackers, pasta, and cereal
# 50                Breads, crackers, pasta, and cereal
# 51                                     Prepared meats
# 52                                     Prepared meats
# 53                          Dried fruit and bean curd
# 54                          Dried fruit and bean curd
# 55                          Dried fruit and bean curd
# 56                          Dried fruit and bean curd
# 57                                   Seaweed and fish
# 58                                   Seaweed and fish
# 59                                   Seaweed and fish
# 60                                   Seaweed and fish
# 61                                   Seaweed and fish
# 62                                   Seaweed and fish
# 63                                   Seaweed and fish
# 64                                   Seaweed and fish
# 65                                   Seaweed and fish
# 66                                   Seaweed and fish
# 67                                   Seaweed and fish
# 68                                   Seaweed and fish
#
# [69 rows x 13 columns]

# %%
demand = pd.read_sql_query("SELECT Discount,UnitsInStock ,UnitsOnOrder ,CategoryId, Discontinued FROM OrderDetail INNER JOIN Product ON OrderDetail.ProductId = Product.Id WHERE Product.Discontinued = 0", conn)

# %%
demand.head()
# Out:
#    Discount  UnitsInStock  UnitsOnOrder  CategoryId  Discontinued
# 0       0.0            22            30           4             0
# 1       0.0            14             0           4             0
# 2       0.0            35             0           7             0
# 3       0.0            20             0           7             0
# 4       0.0            85             0           8             0

# %%
demand.drop(labels="Discontinued", axis=1, inplace=True)

# %%
demand.head()
# Out:
#    Discount  UnitsInStock  UnitsOnOrder  CategoryId
# 0       0.0            22            30           4
# 1       0.0            14             0           4
# 2       0.0            35             0           7
# 3       0.0            20             0           7
# 4       0.0            85             0           8

# %%
demand_ctrl = demand[demand["Discount"] == 0]
demand_exp = demand[demand["Discount"] != 0]

# %% [markdown]
# ### 1.3 Data structure and content

# %%
demand.isna().sum()
# Out:
# Discount        0
# UnitsInStock    0
# UnitsOnOrder    0
# CategoryId      0
# dtype: int64

# %% [markdown]
# No null values that need to be cleaned.

# %%
demand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1927 entries, 0 to 1926
# Data columns (total 4 columns):
# Discount        1927 non-null float64
# UnitsInStock    1927 non-null int64
# UnitsOnOrder    1927 non-null int64
# CategoryId      1927 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 60.3 KB

# %%
demand.describe()
# Out:
#           Discount  UnitsInStock  UnitsOnOrder   CategoryId
# count  1927.000000   1927.000000   1927.000000  1927.000000
# mean      0.056300     43.049818      9.029580     4.066424
# std       0.083328     36.561995     20.677584     2.387173
# min       0.000000      0.000000      0.000000     1.000000
# 25%       0.000000     17.000000      0.000000     2.000000
# 50%       0.000000     26.000000      0.000000     4.000000
# 75%       0.100000     69.000000      0.000000     6.000000
# max       0.250000    125.000000    100.000000     8.000000

# %%
plt.figure(figsize=(25, 15))
sns.distplot(demand['UnitsInStock'], hist='density')
plt.title('Distribution of Units In Stock', fontsize=16)
plt.xlabel('Quantity', fontsize=16)

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(25, 15))
sns.distplot(demand['Discount'], hist='density')
plt.title('Distribution of Discount', fontsize=16)
plt.xlabel('Discount', fontsize=16)

# %% [markdown]
# The **Dependent Variable - Quantity** is positively skewed with a minimum order quantity of 1 and the largest order was 130.  Meaning that most orders include only a few items.  This imaginary business would like to increase the quantity of items sold in each order placed.  Somebody had the idea that the level of discount offered is directly related to the quantity of items a customer orders.  Therefore our **Independent Variable-Discount** is shown above.  We can immediately see that most orders have no discount and the largest discount offered is 25%.  **Discount** is assumed to be assigned to a total order and not individual products.  Also, there is one discount between 0 and 5% that can be eliminated from our dataset making **Discount** an **ordinal variable/feature** that has a very near, but not quite, **uniform distribution** across the 5%, 10%, 15%, 20%, 25% increments.

# %% [markdown]
# **In order to select the most appropriate statistical test, a researcher should answer the following six questions.**<br>
#
# 1) How many variables will we be tracking?<br>
# **2 variables, both are currently assumed to be independent our hypothesis test is interested in discovering a relationship between the IV - Discount and DV - Quantity** br
# 2) At what level of measurement is the independent variable?<br>
# **ordinal- the percentages are discrete yet in rank order**<br>
# 3) What is the level of measurement of the dependent variable?<br>
# **continuous integers**
# 4) Are the observations independent or dependent?<br>
# **We are given no information about how the discount level is chosen when a sale is made.  Therefore, it is assumed that these 2 features are independent**
# 5) Do the comparisons involve populations to populations, a sample to a population, or are two or more samples compared?<br>
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3105563/ read this when I have time
# **I will be creating samples from
# 6) Is the hypothesis being tested comparative or relationship?<br>

# %% [markdown]
# ## 2 Experiment Design

# %% [markdown]
# ### 2.1 Setting up control and experimental groups

# %% [markdown]
# **_Do discounts have a statistically significant effect on the number of products customers order? If so, at what level(s) of discount?_** <br>
#
# - The **control** group is comprised of orders that did not receive a discount<br>
# - The **experimental** group is comprised of orders that did receive a discount<br>

# %%
demand.head()

# %%
demand.rename(index=str, columns={"Discount":"discount", "UnitsInStock":"supply"}, inplace=True)

# %%
demand_ctrl = demand[demand["discount"] == 0]
demand_exp = demand[demand["discount"] != 0]

# %%
demand_exp["discount"].value_counts()

# %%
demand_exp = demand_exp[demand_exp.discount != 0.03]
demand_exp = demand_exp[demand_exp.discount != 0.02]
demand_exp = demand_exp[demand_exp.discount != 0.04]
demand_exp = demand_exp[demand_exp.discount != 0.06]
demand_exp = demand_exp[demand_exp.discount != 0.01]

# %%
demand_exp["discount"].value_counts()

# %%
demand_ctrl.hist(figsize=(20,20))

# %%
demand_ctrl = demand_ctrl.groupby(["supply"])

# %%
demand_ctrl

# %% [markdown]
# ### 2.2 Checking Assumptions

# %% [markdown]
# #### 2.2.1 Normality

# %% [markdown]
# In order to perform a two-sample t-test, there are several assumptions that need to be met, the first of which is normality. We will assess this visually and also perform a normality test using the [normaltest function](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.normaltest.html#scipy.stats.normaltest) which combines measures of skew and kurtosis.

# %%
labels = ['Control','Experimental']
for ind, i in enumerate([ctrl, exp]):
    print (labels[ind])
    plt.hist(i)
    sm.qqplot(i, line='s')
    

    plt.show()

# %%
# visual check for normality
plt.figure(figsize=(20, 10))
sns.distplot(ctrl, label='Control')
sns.distplot(exp, label='Experimental',kde=True, hist=True )
plt.title('Visual Check for Normality', fontsize=25)
plt.xlabel('Quantity/Order', fontsize=20)
plt.legend(fontsize=55);

# %% [markdown]
# We can see that both the control and test data sets are skewed positive through visual inspection we will now check that observation using scipy's normal test function.

# %%
# Use scipy's normal test function for both groups
import scipy.stats as stat

print('Normality of distribution: ', stat.normaltest(ctrl))
print('Normality of distribution: ', stat.normaltest(exp))

# %% [markdown]
# statistic = s^2 + k^2 = Skewness + Kurtosis

# %%
stat.skewtest(ctrl)

# %%
stat.kurtosistest(ctrl)

# %%
19.36939831677361**2 + 13.015506651733459**2 == 544.5770045551502

# %% [markdown]
# If the visual was not obvious enough, such a low p-value result from the scipy.stats.normaltest results should remove all doubt.  The resulting distribution is non-normal.  The results of both the experimental and control groups are positively skewed.  We can still use this sample thanks to the **Central Limit Theorem**.

# %% [markdown]
# #### 2.2.2 Independence

# %% [markdown]
# The next assumption is independence both within and between groups. This assumption is satisfied because one order is not related to the other.  If the variables were dependent we would be given some information that the price of an item increases or decreases depending on supply/demand.  Since we are not told this we assume the variables are completely independent satisfying the independence assumption.

# %% [markdown]
# #### 2.2.3 Random
#
# The last assumption is that samples are randomly chosen, meaning every observation has an equal chance of being selected. When we create the sampling distribution of sample mean, we will use numpy's [random.choice function](https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html) to ensure a random sample is generated.

# %% [markdown]
# ### 2.3 Creating a Sampling Distribution of Sample Mean

# %%
sample = ctrl+exp

# %%
len(ctrl)

# %%
len(exp)

# %% [markdown]
# the mean value of discount applied treatement group or experimental group is about 5.4 units greater than the control group. We need to figure out if this is really significant by randomly selecting from an entire population where both groups are together. This will reduce the sensitivity to outliers and determine the probability that the larger value within the treatment group is actually just random luck.  We are hoping for a p-value of less than .05 so that we may reject the null hypothesis and take one step closer to recommending that the discounts do increase the amount of units sold.  What percentage of our tests will have a difference greater than 5.4?

# %%
#taking a look at the means
print("control " + str(ctrl.mean()))
print("experimental " + str(exp.mean()))

# %%
original_diff = abs(ctrl.mean()-exp.mean())
original_diff

# %%
#check the amount of samples and use 1/2
i = int(np.round(len(df_orders)/2,0))
i

# %%
sample_a = df_orders["Quantity"].sample(1078)
sample_b = df_orders.drop(sample_a.index)["Quantity"]

# %%
sample_diff = np.mean(sample_a) - np.mean(sample_b)
sample_diff

# %%
# %%time
my_diffs = []
for i in range(10000):
    sample_a = df_orders["Quantity"].sample(1078)
    sample_b = df_orders.drop(sample_a.index)["Quantity"]
    diff = np.mean(sample_a) - np.mean(sample_b)
    my_diffs.append(diff)

# %%
plt.hist(my_diffs)
plt.axvline(original_diff, color = 'k', linewidth = 5)
plt.show()

# %%
sample_a

# %% [markdown]
# Visually I am convinced that the difference between quantity when a discount is provided vs the control (when there is no discount) is a statistically significant difference.  But I need an actual p-value

# %%
my_count = 0
for indv_diff in my_diffs:
    if indv_diff > original_diff:
        my_count += 1

# %%
my_count/len(my_diffs)

# %% [markdown]
# ## 3 Two Sample t-test

# %% [markdown]
# ### 3.1 Hypotheses, Type 1 & Type 2 errors

# %% [markdown]
# The null and alternative hypotheses are as follows:
#
# $H_o:$ There is no difference in...
#
# $H_a:$
#
# We set the significance level ($\alpha$) to 0.05 or 5%. In other words, this is the $\alpha$ value we are comfortable with for making a Type I error which we consider to be more serious than a Type II error. It is important to identify these errors early on so we can improve the test design. With this in mind, what we are trying to do is minimize the probability of committing a Type I error by maximizing the power (probability of making the correct decision when $H_a$ is true). This is one of the reasons why we chose a large sample size.
#
# Type I error: reject 'discount amount has no effect' when it has no effect (i.e. keep offering discounts when it has no effect, resulting in lower revenue)
#
# Type II error: accept 'discount amount has no effect' when it does have an effect (i.e. offer no discounts when it actually has an effect on quantity of product ordered, fail to capture potential revenue)

# %%
ttest_ind(exp.values, ctrl.values )

# %% [markdown]
# the very small p-value confirms that there is a statistically significant difference!

# %% [markdown]
# shouldn't I resample each group individually then run the "normalized" distributions through the t-test?

# %%
# create function to sample with replacement
def get_sample(df, n):
    sample = []
    while len(sample) != n:
        x = np.random.choice(df)
        sample.append(x)
    return sample

# create function to calculate mean of the sample
def get_sample_mean(sample):
    return sum(sample)/len(sample)

# combine functions to create a sample distribution
# create a distribution size of 1000 and sample size of 500
def create_sample_distribution(df, dist_size=1000, n=500):
    sample_dist = [] 
    while len(sample_dist) != dist_size:
        sample = get_sample(df, n)
        sample_mean = get_sample_mean(sample)
        sample_dist.append(sample_mean)
        
    return sample_dist

# %%
ctrl_sample = create_sample_distribution(ctrl)
exp_sample = create_sample_distribution(exp)

# %%
ttest_ind(exp.values, ctrl.values )

# %%
# Calculate Sample Variance
def variance(sample):
    sample_mean = np.mean(sample)
    return sum([(i - sample_mean)**2 for i in sample])

def sample_variance(sample1, sample2):
    n_1, n_2 = len(sample1), len(sample2)
    var_1, var_2 = variance(sample1), variance(sample2)
    return (var_1 + var_2)/((n_1 + n_2)-2)

# %%
# Calculate 2 sample t-statistc
def twosample_tstatistic(exp, ctrl):
    exp_mean, ctrl_mean = np.mean(exp), np.mean(ctrl)
    samp_var = sample_variance(exp, ctrl)
    n_e, n_c = len(exp), len(ctrl)
    num = exp_mean - ctrl_mean
    denom = np.sqrt(samp_var * ((1/n_e)+(1/n_c)))
    return num / denom

t_stat = twosample_tstatistic(exp, ctrl)
t_stat

# %% [markdown]
# Given the above information we can calculate area under the curve to find p-value

# %%
# Visualize test statistic

def visualize_t(t_stat, n_control, n_experimental):

    # initialize a matplotlib "figure"
    fig = plt.figure(figsize=(8,5))
    ax = fig.gca()
    
    # generate points on the x axis between -4 and 4:
    xs = np.linspace(-4, 4, 500)

    # use stats.t.pdf to get values on the probability density function for the t-distribution
    
    ys= stats.t.pdf(xs, (n_control+n_experimental-2), 0, 1)
    ax.plot(xs, ys, linewidth=3, color='darkred')

    ax.axvline(t_stat, color='black', linestyle='--', lw=5)
    ax.axvline(-t_stat, color='black', linestyle='--', lw=5)

    plt.show()
    return None

n_control = len(ctrl_sample)
n_experimental = len(exp_sample)
visualize_t(t_stat, n_control, n_experimental)

# %% [markdown]
# ### 3.2 Welch's t-test

# %%
# create control and experimental groups
# put items without the variable we are curious about into control group
control = df_orders[df_orders['Discount'] == 0]
ctrl = control['Quantity']

# put items with the variable we are curious about into experimental group
experimental = df_orders[df_orders['Discount'] != 0]
treatment= experimental["Quantity"]

# %%
def welch_ttest(x, y): 
    ## Welch-Satterthwaite Degrees of Freedom ##
    dof = (x.var()/x.size + y.var()/y.size)**2 / ((x.var()/x.size)**2 / (x.size-1) + (y.var()/y.size)**2 / (y.size-1))
   
    t, p = stats.ttest_ind(x, y, equal_var = False)
    
    print("\n",
          f"Welch's t-test= {t:.4f}", "\n",
          f"p-value = {p:.4f}", "\n",
          f"Welch-Satterthwaite Degrees of Freedom= {dof:.4f}")

welch_ttest(ctrl, treatment)

# %% [markdown]
# ### 3.3 Effect Size

# %% [markdown]
# ## Cohen's $d$
#
# Cohen’s D is one of the most common ways to measure effect size.  As an effect size, Cohen's d is typically used to represent the magnitude of differences between two (or more) groups on a given variable, with larger values representing a greater differentiation between the two groups on that variable.
#
# Cohen’s d is similar to the unpaired t test t value. It relies on Standard Deviations instead of Standard Errors
#
# The basic formula to calculate Cohen’s $d$ is:
#
# > ** $d$ = effect size (difference of means) / pooled standard deviation **
#
# The denominator is the **standardiser**, and it is important to select the most appropriate one for a given dataset. The pooled standard deviation is the average spread of all data points around their group mean (not the overall mean).

# %%
def Cohen_d(group1, group2):

    # Compute Cohen's d.

    # group1: Series or NumPy array
    # group2: Series or NumPy array

    # returns a floating point number 

    diff = group1.mean() - group2.mean()

    n1, n2 = len(group1), len(group2)
    var1 = group1.var()
    var2 = group2.var()

    # Calculate the pooled threshold as shown earlier
    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    
    # Calculate Cohen's d statistic
    d = diff / np.sqrt(pooled_var)
    
    return d

# %%
ctrl_sample = np.array(ctrl_sample)
exp_sample = np.array(exp_sample)

# %% [markdown]
# The denominator of the equation is the standardiser and, it is important to select the most appropriate standardiser for a given dataset because it can have a big influence on Cohen’s d.

# %%
Cohen_d(ctrl_sample,exp_sample)

# %% [markdown]
# large effect = 6.33

# %% [markdown]
# Parameters I am used to when dealing with Cohen's d
#
# parameters
# small effect = 0 to .2 std
# med. effect = .2 to .8 std
# large effect > .8 std
#
# *Our Cohen's d value is 6.33; therefore we can categorize the difference as a small to medium effect size.*

# %% [markdown]
# ### 3.4 One-way ANOVA

# %%
df_orders['Quantity'].groupby(df_orders['Discount']).describe()

# %%
# wrap with C() to indicate categorical variable
results = ols('Quantity ~ C(Discount)', data=df_orders).fit()

# %%
aov_table = sm.stats.anova_lm(results, typ=2)
print(aov_table)

# %%
mc = MultiComparison(df_orders['Quantity'], df_orders['Discount'])
mc_results = mc.tukeyhsd()
print(mc_results)

# %% [markdown]
# ## 4 Additional Hypothesis Tests

# %% [markdown]
# ### 4.1 additional question 1

# %%
#get a list of all tables 
for row in c.execute("SELECT name FROM sqlite_master WHERE type='table';"):
    print(row)

# %%
employee = pd.read_sql_query("SELECT * FROM Employee", conn)
category = pd.read_sql_query("SELECT * FROM Category", conn)
customer = pd.read_sql_query("SELECT * FROM Customer", conn)
shipper = pd.read_sql_query("SELECT * FROM Shipper", conn)
supplier = pd.read_sql_query("SELECT * FROM Supplier", conn)
#order = pd.read_sql_query("SELECT * FROM Order", conn)
product = pd.read_sql_query("SELECT * FROM Product", conn)
order_detail = pd.read_sql_query("SELECT * FROM OrderDetail", conn)
customer_customer_demo = pd.read_sql_query("SELECT * FROM CustomerCustomerDemo", conn)
customer_demographic = pd.read_sql_query("SELECT * FROM CustomerDemographic", conn)
region = pd.read_sql_query("SELECT * FROM Region", conn)
territory = pd.read_sql_query("SELECT * FROM Territory", conn)
employee_territory = pd.read_sql_query("SELECT * FROM EmployeeTerritory", conn)

# %%
print("Dimension of Employee Table is: {}".format(employee.shape))
print(100*" ")
print(employee.info())
print(100*" ")
print(employee.select_dtypes(exclude=['float64','int64']).describe())
print(100*" ")
print(employee.describe())
print(100*" ")
print(employee.isnull().sum(axis=0))

# %%
conn.close()

# %%
def get_order_data(self, telegram_id):
        conn = sqlite3.connect(self._DATABASE)
        sql = """
              SELECT
                danceability, energy, loudness, speechiness, acousticness,
                instrumentalness, liveness, valence, tempo, activity
              FROM songs s, users u, song_user su
              WHERE
                activity IS NOT NULL AND
                s.id = su.song_id AND
                su.user_id = u.id AND
                u.telegram_user_id = {}
        """.format(telegram_id)
        order = pd.read_sql_query(sql, conn)
        conn.close()

        return resp

# %%
order = pd.read_sql_query("SELECT * FROM Order", conn)

# %%
employee_territory.head()

# %%
territory.TerritoryDescription.unique()

# %%
territory.RegionId.unique()

# %%
region

# %%
df_orders.head()

# %% [markdown]
# #### 4.1.2 Retrieve data from database

# %%
control = df_orders[df_orders['Discount'] == 0].copy()
control["Total"]= control['UnitPrice']*control["Quantity"]


experimental = df_orders[df_orders['Discount'] != 0].copy()
experimental["Total"]= experimental["Quantity"]*experimental["UnitPrice"]*(1-experimental["Discount"])

# %%
experimental.sample(20)

# %%
experimental.groupby('OrderId', axis=1, squeeze=True)

# %%
experimental

# %% [markdown]
# null hypothesis - all regions sell the same amount of products
# hypothesis - I've noticed most sales people are westerners so I think that the quantity of sales will be greater in western region.

# %%
order = pd.read_sql_query("SELECT * FROM Orders", conn)

# %% [markdown]
# ## 5 Conclusions

# %% [markdown]
# use bullet points and restate either the null or alternative hypothesis that we found to be true in each experiment respectably.
